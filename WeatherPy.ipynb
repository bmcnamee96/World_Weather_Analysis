# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size=1500)
lngs = np.random.uniform(-180, 180, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# add the lat and lngs to a list
coordinates = list(lat_lngs)

# %%
# create a list for holding the cities
cities = []

# identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if the city is unique, add it to the cities list
    if city not in cities:
        cities.append(city)
# print the city count to confirm sufficient count
len(cities)
# Out:
# 617

# %%
# Import our dependencies
import time
from datetime import datetime

# import the requests library
import requests

# import the api key
from config import weather_api_key

# %%
url = f'http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid={weather_api_key}'

# %%
# create an empty list to hold the weather data
city_data = []

# print the beginning of the logging
print('Beginning Data Retrieval     ')
print('-----------------------------')

# create counters
record_count = 1
set_count = 1

# loop through all the cities in our list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # create endpoint url with each city
    city_url = url + '&q=' + city.replace(' ', '+')
    
    # log the url, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    # add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tyret pervaya
# Processing Record 2 of Set 1 | tocopilla
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | sitka
# Processing Record 5 of Set 1 | chokurdakh
# Processing Record 6 of Set 1 | panique
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | luderitz
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | chuy
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | anadyr
# Processing Record 15 of Set 1 | lorengau
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | victoria
# Processing Record 19 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 1 | poso
# Processing Record 21 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 1 | omsukchan
# Processing Record 23 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 1 | thompson
# Processing Record 25 of Set 1 | russell
# Processing Record 26 of Set 1 | fort nelson
# Processing Record 27 of Set 1 | comodoro rivadavia
# Processing Record 28 of Set 1 | atambua
# Processing Record 29 of Set 1 | tasiilaq
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | khorramabad
# Processing Record 33 of Set 1 | povolzhskiy
# Processing Record 34 of Set 1 | ilulissat
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | pevek
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | barreirinhas
# Processing Record 41 of Set 1 | longyan
# Processing Record 42 of Set 1 | kibaya
# Processing Record 43 of Set 1 | verkhnyaya inta
# Processing Record 44 of Set 1 | ponta do sol
# Processing Record 45 of Set 1 | husavik
# Processing Record 46 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 1 | laurel
# Processing Record 48 of Set 1 | yulara
# Processing Record 49 of Set 1 | cedar rapids
# Processing Record 50 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 2 | tarsus
# Processing Record 2 of Set 2 | east london
# Processing Record 3 of Set 2 | mar del plata
# Processing Record 4 of Set 2 | buariki
# City not found. Skipping...
# Processing Record 5 of Set 2 | arlit
# Processing Record 6 of Set 2 | bengkulu
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | qaanaaq
# Processing Record 9 of Set 2 | saint-philippe
# Processing Record 10 of Set 2 | xudat
# Processing Record 11 of Set 2 | grand gaube
# Processing Record 12 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 2 | villa bisono
# Processing Record 14 of Set 2 | caravelas
# Processing Record 15 of Set 2 | pokhara
# Processing Record 16 of Set 2 | altay
# Processing Record 17 of Set 2 | mahanoro
# Processing Record 18 of Set 2 | samarai
# Processing Record 19 of Set 2 | rocky mountain house
# Processing Record 20 of Set 2 | grindavik
# Processing Record 21 of Set 2 | ponta delgada
# Processing Record 22 of Set 2 | coihaique
# Processing Record 23 of Set 2 | kahului
# Processing Record 24 of Set 2 | belgrade
# Processing Record 25 of Set 2 | karaton
# Processing Record 26 of Set 2 | palmer
# Processing Record 27 of Set 2 | doha
# Processing Record 28 of Set 2 | iqaluit
# Processing Record 29 of Set 2 | torit
# Processing Record 30 of Set 2 | poum
# Processing Record 31 of Set 2 | alta floresta
# Processing Record 32 of Set 2 | pacific grove
# Processing Record 33 of Set 2 | rawson
# Processing Record 34 of Set 2 | narsaq
# Processing Record 35 of Set 2 | provideniya
# Processing Record 36 of Set 2 | general macarthur
# Processing Record 37 of Set 2 | castro
# Processing Record 38 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 2 | cabo san lucas
# Processing Record 40 of Set 2 | vaini
# Processing Record 41 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 2 | brae
# Processing Record 43 of Set 2 | mpulungu
# Processing Record 44 of Set 2 | rio gallegos
# Processing Record 45 of Set 2 | lagoa
# Processing Record 46 of Set 2 | college
# Processing Record 47 of Set 2 | qurayyat
# Processing Record 48 of Set 2 | providencia
# Processing Record 49 of Set 2 | hobyo
# Processing Record 50 of Set 2 | norman wells
# Processing Record 1 of Set 3 | atuona
# Processing Record 2 of Set 3 | upernavik
# Processing Record 3 of Set 3 | alofi
# Processing Record 4 of Set 3 | orange walk
# Processing Record 5 of Set 3 | port elizabeth
# Processing Record 6 of Set 3 | amga
# Processing Record 7 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 8 of Set 3 | tevaitoa
# Processing Record 9 of Set 3 | kodiak
# Processing Record 10 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 3 | bissau
# Processing Record 12 of Set 3 | ancud
# Processing Record 13 of Set 3 | nanortalik
# Processing Record 14 of Set 3 | atar
# Processing Record 15 of Set 3 | batagay
# Processing Record 16 of Set 3 | dryden
# Processing Record 17 of Set 3 | dikson
# Processing Record 18 of Set 3 | novovyazniki
# Processing Record 19 of Set 3 | ishigaki
# Processing Record 20 of Set 3 | panguna
# Processing Record 21 of Set 3 | soledade
# Processing Record 22 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 3 | bethel
# Processing Record 24 of Set 3 | cherskiy
# Processing Record 25 of Set 3 | dwarka
# Processing Record 26 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 3 | aden
# Processing Record 28 of Set 3 | port alfred
# Processing Record 29 of Set 3 | lebu
# Processing Record 30 of Set 3 | skibotn
# Processing Record 31 of Set 3 | port moresby
# Processing Record 32 of Set 3 | jamestown
# Processing Record 33 of Set 3 | qasigiannguit
# Processing Record 34 of Set 3 | sento se
# City not found. Skipping...
# Processing Record 35 of Set 3 | longyearbyen
# Processing Record 36 of Set 3 | dunedin
# Processing Record 37 of Set 3 | sahrak
# City not found. Skipping...
# Processing Record 38 of Set 3 | saldanha
# Processing Record 39 of Set 3 | kamarion
# Processing Record 40 of Set 3 | lata
# Processing Record 41 of Set 3 | port hedland
# Processing Record 42 of Set 3 | sorland
# Processing Record 43 of Set 3 | yasnyy
# Processing Record 44 of Set 3 | khandbari
# Processing Record 45 of Set 3 | torbay
# Processing Record 46 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 3 | oranjemund
# Processing Record 48 of Set 3 | port lincoln
# Processing Record 49 of Set 3 | george
# Processing Record 50 of Set 3 | hofn
# Processing Record 1 of Set 4 | pisco
# Processing Record 2 of Set 4 | lompoc
# Processing Record 3 of Set 4 | hermanus
# Processing Record 4 of Set 4 | hithadhoo
# Processing Record 5 of Set 4 | mareeba
# Processing Record 6 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 4 | santa rosa
# Processing Record 8 of Set 4 | forestville
# Processing Record 9 of Set 4 | kulhudhuffushi
# Processing Record 10 of Set 4 | yamada
# Processing Record 11 of Set 4 | leningradskiy
# Processing Record 12 of Set 4 | oudtshoorn
# Processing Record 13 of Set 4 | toamasina
# Processing Record 14 of Set 4 | hasaki
# Processing Record 15 of Set 4 | puerto escondido
# Processing Record 16 of Set 4 | georgetown
# Processing Record 17 of Set 4 | saint george
# Processing Record 18 of Set 4 | asau
# Processing Record 19 of Set 4 | vung tau
# Processing Record 20 of Set 4 | valkeakoski
# Processing Record 21 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 4 | kaitangata
# Processing Record 23 of Set 4 | fundu moldovei
# Processing Record 24 of Set 4 | dingle
# Processing Record 25 of Set 4 | pitimbu
# Processing Record 26 of Set 4 | silvan
# Processing Record 27 of Set 4 | bluff
# Processing Record 28 of Set 4 | voznesenye
# Processing Record 29 of Set 4 | tiksi
# Processing Record 30 of Set 4 | byron bay
# Processing Record 31 of Set 4 | carnarvon
# Processing Record 32 of Set 4 | yellowknife
# Processing Record 33 of Set 4 | severo-kurilsk
# Processing Record 34 of Set 4 | mizusawa
# Processing Record 35 of Set 4 | valparaiso
# Processing Record 36 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 4 | tiarei
# Processing Record 38 of Set 4 | new norfolk
# Processing Record 39 of Set 4 | ilhabela
# Processing Record 40 of Set 4 | la colmena
# Processing Record 41 of Set 4 | salisbury
# Processing Record 42 of Set 4 | bilma
# Processing Record 43 of Set 4 | kavieng
# Processing Record 44 of Set 4 | lakselv
# Processing Record 45 of Set 4 | laguna
# Processing Record 46 of Set 4 | bereda
# Processing Record 47 of Set 4 | meiringen
# Processing Record 48 of Set 4 | zhuhai
# Processing Record 49 of Set 4 | cedar city
# Processing Record 50 of Set 4 | makakilo city
# Processing Record 1 of Set 5 | venado
# Processing Record 2 of Set 5 | seoul
# Processing Record 3 of Set 5 | kampene
# Processing Record 4 of Set 5 | vostok
# Processing Record 5 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 6 of Set 5 | sal rei
# Processing Record 7 of Set 5 | ketchikan
# Processing Record 8 of Set 5 | ferrol
# Processing Record 9 of Set 5 | yuzhno-kurilsk
# Processing Record 10 of Set 5 | hervey bay
# Processing Record 11 of Set 5 | kampot
# Processing Record 12 of Set 5 | tambovka
# Processing Record 13 of Set 5 | evensk
# Processing Record 14 of Set 5 | ibra
# Processing Record 15 of Set 5 | daphne
# Processing Record 16 of Set 5 | garut
# Processing Record 17 of Set 5 | cao bang
# Processing Record 18 of Set 5 | hailey
# Processing Record 19 of Set 5 | capissayan
# Processing Record 20 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 5 | hohhot
# Processing Record 22 of Set 5 | mount gambier
# Processing Record 23 of Set 5 | avarua
# Processing Record 24 of Set 5 | fort saint james
# Processing Record 25 of Set 5 | santa cruz
# Processing Record 26 of Set 5 | muroto
# Processing Record 27 of Set 5 | shchelyayur
# City not found. Skipping...
# Processing Record 28 of Set 5 | ribeira grande
# Processing Record 29 of Set 5 | una
# Processing Record 30 of Set 5 | kavaratti
# Processing Record 31 of Set 5 | bambous virieux
# Processing Record 32 of Set 5 | lavrentiya
# Processing Record 33 of Set 5 | the valley
# Processing Record 34 of Set 5 | ust-tsilma
# Processing Record 35 of Set 5 | ixtapa
# Processing Record 36 of Set 5 | carutapera
# Processing Record 37 of Set 5 | tshikapa
# Processing Record 38 of Set 5 | hilo
# Processing Record 39 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 5 | san patricio
# Processing Record 41 of Set 5 | elko
# Processing Record 42 of Set 5 | komsomolskiy
# Processing Record 43 of Set 5 | yomitan
# City not found. Skipping...
# Processing Record 44 of Set 5 | hinesville
# Processing Record 45 of Set 5 | malakal
# Processing Record 46 of Set 5 | ostrovnoy
# Processing Record 47 of Set 5 | kalmunai
# Processing Record 48 of Set 5 | tuatapere
# Processing Record 49 of Set 5 | damietta
# Processing Record 50 of Set 5 | florianopolis
# Processing Record 1 of Set 6 | luganville
# Processing Record 2 of Set 6 | edson
# Processing Record 3 of Set 6 | gherghesti
# Processing Record 4 of Set 6 | tual
# Processing Record 5 of Set 6 | derzhavinsk
# Processing Record 6 of Set 6 | biloela
# Processing Record 7 of Set 6 | ixtlahuacan del rio
# Processing Record 8 of Set 6 | zhigansk
# Processing Record 9 of Set 6 | boa vista
# Processing Record 10 of Set 6 | fukue
# Processing Record 11 of Set 6 | brasileia
# Processing Record 12 of Set 6 | meulaboh
# Processing Record 13 of Set 6 | san quintin
# Processing Record 14 of Set 6 | manokwari
# Processing Record 15 of Set 6 | cap malheureux
# Processing Record 16 of Set 6 | dicabisagan
# Processing Record 17 of Set 6 | sungaipenuh
# Processing Record 18 of Set 6 | port augusta
# Processing Record 19 of Set 6 | suntar
# Processing Record 20 of Set 6 | arraial do cabo
# Processing Record 21 of Set 6 | seymchan
# Processing Record 22 of Set 6 | suluq
# Processing Record 23 of Set 6 | srednekolymsk
# Processing Record 24 of Set 6 | portland
# Processing Record 25 of Set 6 | belaya gora
# Processing Record 26 of Set 6 | sao filipe
# Processing Record 27 of Set 6 | igdir
# Processing Record 28 of Set 6 | matias barbosa
# Processing Record 29 of Set 6 | mattru
# Processing Record 30 of Set 6 | krasnoye
# Processing Record 31 of Set 6 | tuktoyaktuk
# Processing Record 32 of Set 6 | vicuna
# Processing Record 33 of Set 6 | sechura
# Processing Record 34 of Set 6 | olafsvik
# Processing Record 35 of Set 6 | nazare
# Processing Record 36 of Set 6 | salamanca
# Processing Record 37 of Set 6 | marystown
# Processing Record 38 of Set 6 | champerico
# Processing Record 39 of Set 6 | jumla
# Processing Record 40 of Set 6 | locri
# Processing Record 41 of Set 6 | ribeira brava
# Processing Record 42 of Set 6 | lazaro cardenas
# Processing Record 43 of Set 6 | hirara
# Processing Record 44 of Set 6 | namibe
# Processing Record 45 of Set 6 | airai
# Processing Record 46 of Set 6 | marrakesh
# Processing Record 47 of Set 6 | kieta
# Processing Record 48 of Set 6 | bima
# Processing Record 49 of Set 6 | black river
# Processing Record 50 of Set 6 | hami
# Processing Record 1 of Set 7 | san cristobal
# Processing Record 2 of Set 7 | moron
# Processing Record 3 of Set 7 | maniitsoq
# Processing Record 4 of Set 7 | conde
# Processing Record 5 of Set 7 | klyuchi
# Processing Record 6 of Set 7 | necochea
# Processing Record 7 of Set 7 | presidente medici
# Processing Record 8 of Set 7 | deputatskiy
# Processing Record 9 of Set 7 | taltal
# Processing Record 10 of Set 7 | sesvete
# Processing Record 11 of Set 7 | kita
# Processing Record 12 of Set 7 | victor harbor
# Processing Record 13 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 14 of Set 7 | inirida
# Processing Record 15 of Set 7 | bodinayakkanur
# Processing Record 16 of Set 7 | ahipara
# Processing Record 17 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 7 | torbat-e jam
# Processing Record 19 of Set 7 | qingdao
# Processing Record 20 of Set 7 | rybinsk
# Processing Record 21 of Set 7 | zhangjiakou
# Processing Record 22 of Set 7 | constitucion
# Processing Record 23 of Set 7 | guerrero negro
# Processing Record 24 of Set 7 | faanui
# Processing Record 25 of Set 7 | fortuna
# Processing Record 26 of Set 7 | beloha
# Processing Record 27 of Set 7 | riyadh
# Processing Record 28 of Set 7 | gasa
# Processing Record 29 of Set 7 | abu dhabi
# Processing Record 30 of Set 7 | mitsamiouli
# Processing Record 31 of Set 7 | san vicente
# Processing Record 32 of Set 7 | kupang
# Processing Record 33 of Set 7 | isangel
# Processing Record 34 of Set 7 | tura
# Processing Record 35 of Set 7 | maceio
# Processing Record 36 of Set 7 | huarmey
# Processing Record 37 of Set 7 | chabahar
# Processing Record 38 of Set 7 | sao miguel do araguaia
# Processing Record 39 of Set 7 | abu samrah
# Processing Record 40 of Set 7 | naze
# Processing Record 41 of Set 7 | broome
# Processing Record 42 of Set 7 | maraa
# Processing Record 43 of Set 7 | nanjing
# Processing Record 44 of Set 7 | lakes entrance
# Processing Record 45 of Set 7 | bouafle
# Processing Record 46 of Set 7 | eden
# Processing Record 47 of Set 7 | varkkallai
# Processing Record 48 of Set 7 | mount hagen
# Processing Record 49 of Set 7 | rio grande
# Processing Record 50 of Set 7 | esperance
# Processing Record 1 of Set 8 | clyde river
# Processing Record 2 of Set 8 | sabha
# Processing Record 3 of Set 8 | pouembout
# Processing Record 4 of Set 8 | puerto del rosario
# Processing Record 5 of Set 8 | sfantu gheorghe
# Processing Record 6 of Set 8 | krasnaya gora
# Processing Record 7 of Set 8 | coquimbo
# Processing Record 8 of Set 8 | khatanga
# Processing Record 9 of Set 8 | guatire
# Processing Record 10 of Set 8 | borovskoy
# Processing Record 11 of Set 8 | taraz
# Processing Record 12 of Set 8 | cairns
# Processing Record 13 of Set 8 | progreso
# Processing Record 14 of Set 8 | savannakhet
# Processing Record 15 of Set 8 | pagudpud
# Processing Record 16 of Set 8 | pervouralsk
# Processing Record 17 of Set 8 | vestmannaeyjar
# Processing Record 18 of Set 8 | kirakira
# Processing Record 19 of Set 8 | takoradi
# Processing Record 20 of Set 8 | saskylakh
# Processing Record 21 of Set 8 | karratha
# Processing Record 22 of Set 8 | urengoy
# Processing Record 23 of Set 8 | mporokoso
# Processing Record 24 of Set 8 | padang
# Processing Record 25 of Set 8 | tolbazy
# Processing Record 26 of Set 8 | nanakuli
# Processing Record 27 of Set 8 | bonfim
# Processing Record 28 of Set 8 | mata
# Processing Record 29 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 30 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 8 | plouzane
# Processing Record 32 of Set 8 | margate
# Processing Record 33 of Set 8 | la ronge
# Processing Record 34 of Set 8 | namtsy
# Processing Record 35 of Set 8 | kumluca
# Processing Record 36 of Set 8 | kolaras
# Processing Record 37 of Set 8 | port hardy
# Processing Record 38 of Set 8 | kontagora
# Processing Record 39 of Set 8 | souillac
# Processing Record 40 of Set 8 | cayenne
# Processing Record 41 of Set 8 | roela
# Processing Record 42 of Set 8 | mitu
# Processing Record 43 of Set 8 | rocha
# Processing Record 44 of Set 8 | kudahuvadhoo
# Processing Record 45 of Set 8 | kabanjahe
# Processing Record 46 of Set 8 | lexington
# Processing Record 47 of Set 8 | okoneshnikovo
# Processing Record 48 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 8 | kloulklubed
# Processing Record 50 of Set 8 | vanimo
# Processing Record 1 of Set 9 | bangkalan
# Processing Record 2 of Set 9 | erenhot
# Processing Record 3 of Set 9 | ostersund
# Processing Record 4 of Set 9 | pauini
# Processing Record 5 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 6 of Set 9 | korgen
# Processing Record 7 of Set 9 | preobrazheniye
# Processing Record 8 of Set 9 | kirando
# Processing Record 9 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 10 of Set 9 | quatre cocos
# Processing Record 11 of Set 9 | richards bay
# Processing Record 12 of Set 9 | aki
# Processing Record 13 of Set 9 | dalby
# Processing Record 14 of Set 9 | leh
# Processing Record 15 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 16 of Set 9 | bubaque
# Processing Record 17 of Set 9 | neyshabur
# Processing Record 18 of Set 9 | chase
# Processing Record 19 of Set 9 | goundam
# Processing Record 20 of Set 9 | nara
# Processing Record 21 of Set 9 | tabas
# Processing Record 22 of Set 9 | biak
# Processing Record 23 of Set 9 | burnie
# Processing Record 24 of Set 9 | ust-omchug
# Processing Record 25 of Set 9 | north battleford
# Processing Record 26 of Set 9 | calama
# Processing Record 27 of Set 9 | west bay
# Processing Record 28 of Set 9 | hambantota
# Processing Record 29 of Set 9 | mugumu
# Processing Record 30 of Set 9 | lugovoy
# Processing Record 31 of Set 9 | tautira
# Processing Record 32 of Set 9 | crixas
# Processing Record 33 of Set 9 | lalomanu
# City not found. Skipping...
# Processing Record 34 of Set 9 | wawa
# Processing Record 35 of Set 9 | statesville
# Processing Record 36 of Set 9 | kokstad
# Processing Record 37 of Set 9 | gurupa
# Processing Record 38 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 39 of Set 9 | gayeri
# Processing Record 40 of Set 9 | yazd
# Processing Record 41 of Set 9 | boddam
# Processing Record 42 of Set 9 | svetlyy
# Processing Record 43 of Set 9 | jurado
# Processing Record 44 of Set 9 | ayan
# Processing Record 45 of Set 9 | bulgan
# Processing Record 46 of Set 9 | tchibanga
# Processing Record 47 of Set 9 | salalah
# Processing Record 48 of Set 9 | veraval
# Processing Record 49 of Set 9 | olden
# Processing Record 50 of Set 9 | hualmay
# Processing Record 1 of Set 10 | saint-pierre
# Processing Record 2 of Set 10 | hamilton
# Processing Record 3 of Set 10 | el wasta
# City not found. Skipping...
# Processing Record 4 of Set 10 | shaoyang
# Processing Record 5 of Set 10 | kidal
# Processing Record 6 of Set 10 | rincon
# Processing Record 7 of Set 10 | langham
# Processing Record 8 of Set 10 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 9 of Set 10 | baniachang
# Processing Record 10 of Set 10 | roebourne
# Processing Record 11 of Set 10 | zheleznodorozhnyy
# Processing Record 12 of Set 10 | beaufort
# Processing Record 13 of Set 10 | faya
# Processing Record 14 of Set 10 | maykain
# City not found. Skipping...
# Processing Record 15 of Set 10 | binga
# Processing Record 16 of Set 10 | pashiya
# Processing Record 17 of Set 10 | agha jari
# City not found. Skipping...
# Processing Record 18 of Set 10 | lasa
# Processing Record 19 of Set 10 | saint-augustin
# Processing Record 20 of Set 10 | geraldton
# Processing Record 21 of Set 10 | kruisfontein
# Processing Record 22 of Set 10 | santa maria
# Processing Record 23 of Set 10 | adrar
# Processing Record 24 of Set 10 | vila velha
# Processing Record 25 of Set 10 | boyolangu
# Processing Record 26 of Set 10 | kachug
# Processing Record 27 of Set 10 | bitkine
# Processing Record 28 of Set 10 | balaipungut
# Processing Record 29 of Set 10 | taoudenni
# Processing Record 30 of Set 10 | matara
# Processing Record 31 of Set 10 | arapongas
# Processing Record 32 of Set 10 | ontario
# Processing Record 33 of Set 10 | andilamena
# Processing Record 34 of Set 10 | kayerkan
# Processing Record 35 of Set 10 | puerto palomas
# Processing Record 36 of Set 10 | cervo
# Processing Record 37 of Set 10 | marfino
# Processing Record 38 of Set 10 | setermoen
# Processing Record 39 of Set 10 | alvaraes
# Processing Record 40 of Set 10 | tikrit
# Processing Record 41 of Set 10 | umm kaddadah
# Processing Record 42 of Set 10 | talnakh
# Processing Record 43 of Set 10 | whitehorse
# Processing Record 44 of Set 10 | manono
# Processing Record 45 of Set 10 | gallup
# Processing Record 46 of Set 10 | pringsewu
# Processing Record 47 of Set 10 | vega de alatorre
# Processing Record 48 of Set 10 | sur
# Processing Record 49 of Set 10 | batemans bay
# Processing Record 50 of Set 10 | beringovskiy
# Processing Record 1 of Set 11 | delvada
# Processing Record 2 of Set 11 | cidreira
# Processing Record 3 of Set 11 | jiblah
# Processing Record 4 of Set 11 | bandarbeyla
# Processing Record 5 of Set 11 | la rioja
# Processing Record 6 of Set 11 | mooresville
# Processing Record 7 of Set 11 | cocorit
# Processing Record 8 of Set 11 | pandan
# Processing Record 9 of Set 11 | vylkove
# Processing Record 10 of Set 11 | lieto
# Processing Record 11 of Set 11 | capreol
# Processing Record 12 of Set 11 | chernyshevskiy
# Processing Record 13 of Set 11 | mahebourg
# Processing Record 14 of Set 11 | nalut
# Processing Record 15 of Set 11 | port-cartier
# Processing Record 16 of Set 11 | manta
# Processing Record 17 of Set 11 | aboso
# Processing Record 18 of Set 11 | tilichiki
# Processing Record 19 of Set 11 | jatai
# Processing Record 20 of Set 11 | launceston
# Processing Record 21 of Set 11 | luanda
# Processing Record 22 of Set 11 | fallon
# Processing Record 23 of Set 11 | klaksvik
# Processing Record 24 of Set 11 | shelburne
# Processing Record 25 of Set 11 | navabad
# City not found. Skipping...
# Processing Record 26 of Set 11 | lipin bor
# Processing Record 27 of Set 11 | urucui
# Processing Record 28 of Set 11 | barra do garcas
# Processing Record 29 of Set 11 | tucuma
# Processing Record 30 of Set 11 | noumea
# Processing Record 31 of Set 11 | waipawa
# Processing Record 32 of Set 11 | touros
# Processing Record 33 of Set 11 | yashkino
# Processing Record 34 of Set 11 | kano
# Processing Record 35 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 11 | akdepe
# Processing Record 37 of Set 11 | sinnamary
# Processing Record 38 of Set 11 | marsh harbour
# Processing Record 39 of Set 11 | kolo
# Processing Record 40 of Set 11 | parchim
# Processing Record 41 of Set 11 | xiaoweizhai
# Processing Record 42 of Set 11 | bid
# City not found. Skipping...
# Processing Record 43 of Set 11 | dolores
# Processing Record 44 of Set 11 | sibolga
# Processing Record 45 of Set 11 | cerrito
# Processing Record 46 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 11 | namatanai
# Processing Record 48 of Set 11 | yeletskiy
# City not found. Skipping...
# Processing Record 49 of Set 11 | maragogi
# Processing Record 50 of Set 11 | isoka
# Processing Record 1 of Set 12 | soure
# Processing Record 2 of Set 12 | mount isa
# Processing Record 3 of Set 12 | mukhanovo
# City not found. Skipping...
# Processing Record 4 of Set 12 | barranca
# Processing Record 5 of Set 12 | acapulco
# Processing Record 6 of Set 12 | matagami
# Processing Record 7 of Set 12 | mikhaylovka
# Processing Record 8 of Set 12 | kendari
# Processing Record 9 of Set 12 | alyangula
# Processing Record 10 of Set 12 | puerto penasco
# Processing Record 11 of Set 12 | caconda
# Processing Record 12 of Set 12 | itarema
# Processing Record 13 of Set 12 | khandagayty
# Processing Record 14 of Set 12 | gayny
# Processing Record 15 of Set 12 | mocuba
# Processing Record 16 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 12 | camacha
# Processing Record 18 of Set 12 | le vauclin
# Processing Record 19 of Set 12 | lalmohan
# Processing Record 20 of Set 12 | balkanabat
# Processing Record 21 of Set 12 | damavand
# Processing Record 22 of Set 12 | opuwo
# Processing Record 23 of Set 12 | la romana
# Processing Record 24 of Set 12 | chake chake
# Processing Record 25 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 12 | mizan teferi
# Processing Record 27 of Set 12 | mehamn
# Processing Record 28 of Set 12 | viana
# Processing Record 29 of Set 12 | batagay-alyta
# Processing Record 30 of Set 12 | berdigestyakh
# Processing Record 31 of Set 12 | thio
# Processing Record 32 of Set 12 | imelda
# Processing Record 33 of Set 12 | qui nhon
# Processing Record 34 of Set 12 | gigmoto
# Processing Record 35 of Set 12 | phuket
# Processing Record 36 of Set 12 | henties bay
# Processing Record 37 of Set 12 | kerteh
# City not found. Skipping...
# Processing Record 38 of Set 12 | kodinar
# Processing Record 39 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 12 | berlevag
# Processing Record 41 of Set 12 | kjopsvik
# Processing Record 42 of Set 12 | marzuq
# Processing Record 43 of Set 12 | fairbanks
# Processing Record 44 of Set 12 | iquitos
# Processing Record 45 of Set 12 | palauig
# Processing Record 46 of Set 12 | aksha
# Processing Record 47 of Set 12 | xining
# Processing Record 48 of Set 12 | palmerston
# Processing Record 49 of Set 12 | puerto madryn
# Processing Record 50 of Set 12 | codrington
# Processing Record 1 of Set 13 | itigi
# Processing Record 2 of Set 13 | sept-iles
# Processing Record 3 of Set 13 | agadez
# Processing Record 4 of Set 13 | dien bien
# City not found. Skipping...
# Processing Record 5 of Set 13 | panama city
# Processing Record 6 of Set 13 | puri
# Processing Record 7 of Set 13 | yokadouma
# Processing Record 8 of Set 13 | inta
# Processing Record 9 of Set 13 | haapu
# City not found. Skipping...
# Processing Record 10 of Set 13 | rize
# Processing Record 11 of Set 13 | orlovskiy
# Processing Record 12 of Set 13 | turtas
# Processing Record 13 of Set 13 | merauke
# Processing Record 14 of Set 13 | chauk
# Processing Record 15 of Set 13 | inhambane
# Processing Record 16 of Set 13 | haines junction
# Processing Record 17 of Set 13 | mayo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# convert the array of distionaries to a df
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Tyret Pervaya  53.6703  102.3106     22.24        97         100
# 1      Tocopilla -22.0920  -70.1979     71.35        66           8
# 2          Sitka  57.0531 -135.3300     37.87        98         100
# 3     Chokurdakh  70.6333  147.9167    -20.88       100          59
# 4        Panique  12.4797  122.0153     80.28        75          47
#
#    Wind Speed Country                 Date
# 0        2.95      RU  2022-04-03 16:00:44
# 1        7.45      CL  2022-04-03 16:00:44
# 2       15.46      US  2022-04-03 16:00:44
# 3        2.93      RU  2022-04-03 16:00:45
# 4       18.61      PH  2022-04-03 16:00:45

# %%
# reorder the columns
new_column_order = ['City', 'Cloudiness', 'Country', 'Date', 'Humidity', 'Lat', 'Lng', 'Max Temp', 'Wind Speed']
city_data_df = city_data_df[new_column_order]

# %%
# create the output file (CSV)
output_data_file = 'weather_data/cities.csv'

# export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label = 'City_ID')

# %%
# extract relevant fields from the df for plotting
lats = city_data_df['Lat']
max_temps = city_data_df['Max Temp']
humidity = city_data_df['Humidity']
cloudiness = city_data_df['Cloudiness']
wind_speed = city_data_df['Wind Speed']

# %%
# import the time module
import time
# get today's date in seconds
today = time.strftime('%x')
today
# Out:
# '04/03/22'

# %%
# build the scatter plot for lat vs max temp
plt.scatter(lats,
           max_temps,
           edgecolor = 'black',
           linewidths = 1,
           marker = 'o',
           alpha = 0.8,
           label = 'Cities')

# incorporate the other graph properties
plt.title(f' City Latitude vs. Max Temperature ' + today)
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid(True)

# save the figure
plt.savefig('weather_data/Fig1.png')

# show the plot
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ today)
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ today)
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ today)
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# import lineregress
from scipy.stats import linregress

# create a function to create perform linear regression on the weather data and plot a regression line and the equation with the data
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # run regression on hemisphere weather data
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # calculate the regression line 'y values' from the slope and intercept
    regress_values = x_values * slope + intercept
    
    # get the equation of the line
    line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
    
    # create a scatter plot and plot the regression line
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, 'r')
    
    # annotate the txt for the line equation
    plt.annotate(line_eq, text_coordinates, fontsize = 15, color = 'red')
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# create northern and southern hemisphere dfs
northern_hemi_df = city_data_df.loc[(city_data_df['Lat'] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df['Lat'] < 0)]

# %%
# linear regression on the northern hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
# call the function 
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for Maximum Temperature', 'Max Temp', (0, 0))

# %%
# linear regression on the souther hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
# call the function 
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for Maximum Temperature', 'Max Temp', (-30, 50))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for % Humidity', '% Humidity',(47,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for % Cloudiness', '% Cloudiness',(47,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(-55,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed',(40,25))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed',(-30,35))
